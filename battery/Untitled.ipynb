# %%
# %ls
# Out:
# '03-18-17_02.17 25degC_Cycle_1_Pan18650PF.mat'   Untitled.ipynb

# %%
import scipy.io
mat = scipy.io.loadmat('03-18-17_02.17 25degC_Cycle_1_Pan18650PF.mat')

# %%
mat.keys()
# Out:
# dict_keys(['__header__', '__version__', '__globals__', 'meas'])

# %%
mat['meas'][0][0][1]
# Out:
# array([[4.14585],
#        [4.10532],
#        [4.08666],
#        ...,
#        [3.2961 ],
#        [3.2961 ],
#        [3.2961 ]])

# %%
x.dtype.fields
# Out:
# mappingproxy({'TimeStamp': (dtype('O'), 0),
#               'Voltage': (dtype('O'), 8),
#               'Current': (dtype('O'), 16),
#               'Ah': (dtype('O'), 24),
#               'Wh': (dtype('O'), 32),
#               'Power': (dtype('O'), 40),
#               'Battery_Temp_degC': (dtype('O'), 48),
#               'Time': (dtype('O'), 56),
#               'Chamber_Temp_degC': (dtype('O'), 64)})

# %%
len(x[0])
# Out:
# 9

# %%
import pandas as pd
x=mat['meas'][0]
data={}
for i,k in enumerate(x.dtype.fields):
    #print(k,[i[0][0] for i in x[0][0]])
    data[k]=[j[0] for j in x[0][i]]
df=pd.DataFrame(data)

# %%
a=df.plot(subplots=True, figsize=(15,6))

# %%
x[0][i]
# Out:
# array([[4.14585],
#        [4.10532],
#        [4.08666],
#        ...,
#        [3.2961 ],
#        [3.2961 ],
#        [3.2961 ]])

# %%
x[0][0][0][0][0]
# Out:
# '3/18/2017 2:17:35 AM'

# %%
y=x[0][0][0]

# %%
# Out:
# ['3/18/2017 2:17:35 AM',
#  '3/18/2017 2:17:35 AM',
#  '3/18/2017 2:17:35 AM',
#  '3/18/2017 2:17:35 AM',
#  '3/18/2017 2:17:35 AM',
#  '3/18/2017 2:17:35 AM',
#  '3/18/2017 2:17:35 AM',
#  '3/18/2017 2:17:35 AM',
#  '3/18/2017 2:17:36 AM',
#  '3/18/2017 2:17:36 AM',
#  '3/18/2017 2:17:36 AM',
#  '3/18/2017 2:17:36 AM',
#  '3/18/2017 2:17:36 AM',
#  '3/18/2017 2:17:36 AM',
#  '3/18/2017 2:17:36 AM',
#  '3/18/2017 2:17:36 AM',
#  '3/18/2017 2:17:36 AM',
#  '3/18/2017 2:17:36 AM',
#  '3/18/2017 2:17:36 AM',
#  '3/18/2017 2:17:37 AM',
#  '3/18/2017 2:17:37 AM',
#  '3/18/2017 2:17:37 AM',
#  '3/18/2017 2:17:37 AM',
#  '3/18/2017 2:17:37 AM',
#  '3/18/2017 2:17:37 AM',
#  '3/18/2017 2:17:37 AM',
#  '3/18/2017 2:17:37 AM',
#  '3/18/2017 2:17:37 AM',
#  '3/18/2017 2:17:37 AM',
#  '3/18/2017 2:17:38 AM',
#  '3/18/2017 2:17:38 AM',
#  '3/18/2017 2:17:38 AM',
#  '3/18/2017 2:17:38 AM',
#  '3/18/2017 2:17:38 AM',
#  '3/18/2017 2:17:38 AM',
#  '3/18/2017 2:17:38 AM',
#  '3/18/2017 2:17:38 AM',
# ...

# %%
y=x[0][0][0]

# %%
y[0][0][i]
# Out:
# '1'
