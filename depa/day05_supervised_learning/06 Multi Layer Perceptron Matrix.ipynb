# %% [markdown]
# # 06 Multi Layer Perceptron Matrix

# %% [markdown]
# # Generating Data

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.cm as cm
plt.style.use('ggplot')
import numpy as np
n=200

#polar coordinate
r1=8+np.random.randn(n)
theta1=np.random.rand(n)*2.0*np.pi

r2=2+np.random.randn(n)
theta2=np.random.rand(n)*2.0*np.pi

x1=np.concatenate( (r1*np.cos(theta1), r2*np.cos(theta2)))
x2=np.concatenate( (r1*np.sin(theta1), r2*np.sin(theta2)))
yt=np.ones( (2*n,1))
yt[n:]=-1
plt.axis('equal')
plt.plot(x1[(yt==1)[:,0]],x2[(yt==1)[:,0]],'.b')
plt.plot(x1[(yt==-1)[:,0]],x2[(yt==-1)[:,0]],'.r')

# %%
x=np.concatenate( (x1.reshape((-1,1)), x2.reshape((-1,1))), axis=1 )
x.shape
# Out:
# (400, 2)

# %%
def forward(a,w,b):
    z=np.dot(a,w)+b
    return np.tanh(z)

def g(a):
    return 1-a*a

# %% [markdown]
# # Setup Neural Network and Backpropagation

# %%
k0=2
k1=3
k2=1
w1=np.random.randn(k0,k1)
b1=np.random.randn(1,k1)
w2=np.random.randn(k1,k2)
b2=np.random.randn(1,k2)
m=1000
alpha=0.001
for i in range(m):
    #forward
    a1=x
    a2=forward(a1,w1,b1)
    a3=forward(a2,w2,b2)
    yp=a3
    L=0.5*np.average((yp-yt)*(yp-yt))
    #back propagation
    da3= (yp-yt)*g(a3)
    dz2= np.dot(da3,w2.T)
    da2= dz2*g(a2)
    w1=w1-alpha*np.dot(a1.T, da2)
    b1=b1-alpha*np.sum(da2,axis=0)
    w2=w2-alpha*np.dot(a2.T, da3)
    b2=b2-alpha*np.sum(da3,axis=0)
    if i%(m//10)==0:
        print("Loss: %s"%L)
        #print(" w1:%s, b1:%s, w2:%s, b2:%s "%(w1,b1,w2,b2) )
# Out:
# Loss: 0.7424084860974576
# Loss: 0.23554162113239685
# Loss: 0.16618369966768548
# Loss: 0.16429325152018834
# Loss: 0.16337294102921007
# Loss: 0.1621662420918632
# Loss: 0.15102466105859902
# Loss: 0.020531204783945513
# Loss: 0.011824322909428517
# Loss: 0.008649197938324762

# %% [markdown]
# # Result

# %%
my,mx=np.mgrid[slice(-10,10,0.1),slice(-10,10,0.1)]
out=np.zeros(mx.shape)
for i in range(mx.shape[0]):
    for j in range(mx.shape[1]):
        u=[ mx[i,j], my[i,j]]
        #forward
        a1=u
        a2=forward(a1,w1,b1)
        a3=forward(a2,w2,b2)
        yp=a3
        out[i,j]=yp
fig=plt.figure(figsize=(12,10))
ax = fig.gca()
ax.set_ylabel(r'$x_1$')
ax.set_xlabel(r'$x_2$')
ax.set_title(r'$circles$')

plt.pcolor(mx,my,out,cmap=cm.PiYG)
plt.colorbar()
plt.axis('equal')
plt.plot(x1[(yt==1)[:,0]],x2[(yt==1)[:,0]],'ob')
plt.plot(x1[(yt==-1)[:,0]],x2[(yt==-1)[:,0]],'or');

# %%
a3.shape
# Out:
# (1, 1)

# %%
yt.shape
# Out:
# (200, 1)
